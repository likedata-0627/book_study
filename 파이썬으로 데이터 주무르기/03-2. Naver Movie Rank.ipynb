# %% [markdown]
# ### 3-2-1 네이버 영화 평점 기준 영화의 평점 변화확인하기

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

url ='https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20200216'

page = urlopen(url)

soup = BeautifulSoup(page, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20200216" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div','tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=171539" title="그린 북">그린 북</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=181710" title="포드 V 페라리">포드 V 페라리</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=189111" title="두 교황">두 교황</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=187308" title="조조 래빗">조조 래빗</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=76667" title="울지마 톤즈">울지마 톤즈</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=172780" title="스파이 지니어스">스파이 지니어스</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=185275" title="미안해요, 리키">미안해요, 리키</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=29059" title="피아니스트의 전설">피아니스트의 전설</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=52515" title="인셉션">인셉션</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div','tit5')[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.nhn?code=171539" title="그린 북">그린 북</a>
# </div>

# %%
soup.find_all('div','tit5')[0].a
# Out:
# <a href="/movie/bi/mi/basic.nhn?code=171539" title="그린 북">그린 북</a>

# %%
soup.find_all('div','tit5')[0].a.string
# Out:
# '그린 북'

# %%
soup.find_all('td','point')
# Out:
# [<td class="point">9.61</td>,
#  <td class="point">9.51</td>,
#  <td class="point">9.35</td>,
#  <td class="point">9.35</td>,
#  <td class="point">9.34</td>,
#  <td class="point">9.33</td>,
#  <td class="point">9.29</td>,
#  <td class="point">9.26</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.20</td>,
#  <td class="point">9.13</td>,
#  <td class="point">9.11</td>,
#  <td class="point">9.07</td>,
#  <td class="point">9.02</td>,
#  <td class="point">9.01</td>,
#  <td class="point">8.95</td>,
#  <td class="point">8.95</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.85</td>,
#  <td class="point">8.82</td>,
#  <td class="point">8.81</td>,
#  <td class="point">8.71</td>,
#  <td class="point">8.66</td>,
#  <td class="point">8.61</td>,
#  <td class="point">8.54</td>,
#  <td class="point">8.50</td>,
#  <td class="point">8.29</td>,
#  <td class="point">8.26</td>,
#  <td class="point">7.99</td>,
#  <td class="point">7.97</td>,
#  <td class="point">7.95</td>,
# ...

# %%
len(soup.find_all('td','point'))
# Out:
# 43

# %%
soup.find_all('td','point')[0].string
# Out:
# '9.61'

# %%
movie_name =[soup.find_all('div','tit5')[n].a.string for n in range(0,43)]
movie_name
# Out:
# ['그린 북',
#  '포드 V 페라리',
#  '두 교황',
#  '조조 래빗',
#  '울지마 톤즈',
#  '스파이 지니어스',
#  '미안해요, 리키',
#  '피아니스트의 전설',
#  '인셉션',
#  '어느 가족',
#  '나이브스 아웃',
#  '러브레터',
#  '결혼 이야기',
#  '비긴 어게인',
#  '타오르는 여인의 초상',
#  '윤희에게',
#  '작은 아씨들',
#  '바르다가 사랑한 얼굴들',
#  '미드웨이',
#  '벌새',
#  '아이리시맨',
#  '겨울왕국 2',
#  '조커',
#  '그녀에게',
#  '졸업',
#  '기생충',
#  '덩케르크',
#  '메기',
#  '라붐',
#  '정직한 후보',
#  '21 브릿지: 테러 셧다운',
#  '종이 달',
#  '날씨의 아이',
#  '원스 어폰 어 타임... 인 할리우드',
#  '남산의 부장들',
#  '히트맨',
#  '공기인형',
#  '클로젯',
#  '82년생 김지영',
#  '버즈 오브 프레이(할리 퀸의 황홀한 해방)',
#  '해치지않아',
#  '대통령의 7시간',
#  '백두산']

# %%
movie_point = [soup.find_all('td','point')[n].string for n in range(0,43)]
movie_point
# Out:
# ['9.61',
#  '9.51',
#  '9.35',
#  '9.35',
#  '9.34',
#  '9.33',
#  '9.29',
#  '9.26',
#  '9.22',
#  '9.20',
#  '9.13',
#  '9.11',
#  '9.07',
#  '9.02',
#  '9.01',
#  '8.95',
#  '8.95',
#  '8.88',
#  '8.85',
#  '8.82',
#  '8.81',
#  '8.71',
#  '8.66',
#  '8.61',
#  '8.54',
#  '8.50',
#  '8.29',
#  '8.26',
#  '7.99',
#  '7.97',
#  '7.95',
#  '7.91',
#  '7.90',
#  '7.65',
#  '7.44',
#  '7.15',
#  '7.09',
#  '6.96',
#  '6.69',
#  '6.64',
#  '6.16',
#  '5.96',
#  '5.79']

# %%
date = pd.date_range('2019-02-16', periods=100, freq ='D')
date
# Out:
# DatetimeIndex(['2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19',
#                '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-23',
#                '2019-02-24', '2019-02-25', '2019-02-26', '2019-02-27',
#                '2019-02-28', '2019-03-01', '2019-03-02', '2019-03-03',
#                '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-07',
#                '2019-03-08', '2019-03-09', '2019-03-10', '2019-03-11',
#                '2019-03-12', '2019-03-13', '2019-03-14', '2019-03-15',
#                '2019-03-16', '2019-03-17', '2019-03-18', '2019-03-19',
#                '2019-03-20', '2019-03-21', '2019-03-22', '2019-03-23',
#                '2019-03-24', '2019-03-25', '2019-03-26', '2019-03-27',
#                '2019-03-28', '2019-03-29', '2019-03-30', '2019-03-31',
#                '2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04',
#                '2019-04-05', '2019-04-06', '2019-04-07', '2019-04-08',
# ...

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html ='https://movie.naver.com/'+\
    'movie/sdb/rank/rmovie.nhn?sel=cur&date={date}'
    response = urlopen(html.format(date=urllib.parse.quote(today.strftime('%Y%m%d'))))
    
    soup = BeautifulSoup(response, 'html.parser')
    
    end = len(soup.find_all('td','point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div','tit5')[n].a.string for n in range(0,end)])
    movie_point.extend([soup.find_all('td','point')[n].string for n in range(0,end)])
# Out:
# C:\Users\kiminae\Anaconda3\envs\study\lib\site-packages\ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (4590, 4590, 4590)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date        name point
# 0 2019-02-16        그린 북  9.65
# 1 2019-02-16        가버나움  9.59
# 2 2019-02-16    보헤미안 랩소디  9.44
# 3 2019-02-16         언더독  9.43
# 4 2019-02-16  폴란드로 간 아이들  9.40

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4590 entries, 0 to 4589
# Data columns (total 3 columns):
# date     4590 non-null datetime64[ns]
# name     4590 non-null object
# point    4590 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 107.7+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4590 entries, 0 to 4589
# Data columns (total 3 columns):
# date     4590 non-null datetime64[ns]
# name     4590 non-null object
# point    4590 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 107.7+ KB

# %%
import numpy as np

movie_unique=pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#          point
# name
# 그린 북    962.45
# 가버나움    959.86
# 인생 후르츠  906.52
# 일일시호일   886.63
# 극한직업    738.55

# %%
tmp = movie.query('name == ["극한직업"]')
tmp
# Out:
#            date  name  point
# 25   2019-02-16  극한직업   8.72
# 64   2019-02-17  극한직업   8.71
# 102  2019-02-18  극한직업   8.70
# 140  2019-02-19  극한직업   8.70
# 179  2019-02-20  극한직업   8.69
# 219  2019-02-21  극한직업   8.69
# 260  2019-02-22  극한직업   8.68
# 303  2019-02-23  극한직업   8.68
# 345  2019-02-24  극한직업   8.68
# 385  2019-02-25  극한직업   8.67
# 428  2019-02-26  극한직업   8.67
# 469  2019-02-27  극한직업   8.67
# 512  2019-02-28  극한직업   8.66
# 556  2019-03-01  극한직업   8.66
# 598  2019-03-02  극한직업   8.66
# 643  2019-03-03  극한직업   8.66
# 689  2019-03-04  극한직업   8.66
# 734  2019-03-05  극한직업   8.66
# 778  2019-03-06  극한직업   8.66
# 822  2019-03-07  극한직업   8.66
# 864  2019-03-08  극한직업   8.66
# 906  2019-03-09  극한직업   8.66
# 948  2019-03-10  극한직업   8.65
# 990  2019-03-11  극한직업   8.65
# 1032 2019-03-12  극한직업   8.65
# 1075 2019-03-13  극한직업   8.65
# 1117 2019-03-14  극한직업   8.63
# 1158 2019-03-15  극한직업   8.62
# 1203 2019-03-16  극한직업   8.61
# 1247 2019-03-17  극한직업   8.60
# ...         ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
movie_best.head(10)
# Out:
#                       point
# name
# 그린 북                 962.45
# 가버나움                 959.86
# 인생 후르츠               906.52
# 일일시호일                886.63
# 극한직업                 738.55
# 더 페이버릿: 여왕의 여자       667.87
# 보헤미안 랩소디             631.72
# 증인                   616.46
# 극장판 헬로카봇:옴파로스 섬의 비밀  605.36
# 칠곡 가시나들              589.49

# %% [markdown]
# ### 3-2-2 영화별 날짜 변화에 따른 평점 변화 확인하기

# %%
movie_pivot = pd.pivot_table(movie, index=['date'], columns=['name'], values =['point'])
movie_pivot.head()
# Out:
#               point                                                       \
# name       1919 유관순 4월 이야기 PMC: 더 벙커  가버나움 가위손 가장 따뜻한 색, 블루 감시자들 걸캅스  공작
# date
# 2019-02-16      NaN    NaN       NaN  9.59 NaN          NaN  NaN NaN NaN
# 2019-02-17      NaN    NaN       NaN  9.59 NaN          NaN  NaN NaN NaN
# 2019-02-18      NaN    NaN       NaN  9.59 NaN          NaN  NaN NaN NaN
# 2019-02-19      NaN    NaN       NaN  9.59 NaN          NaN  NaN NaN NaN
# 2019-02-20      NaN    NaN      5.24  9.58 NaN          NaN  NaN NaN NaN
#
#                    ...                                                   \
# name       공포의 묘지  ...    플립 피아니스트 항거:유관순 이야기 해피 데스데이 2 유 헬보이 현기증    혈투
# date               ...
# 2019-02-16    NaN  ...   NaN   NaN        NaN        8.06 NaN NaN  5.25
# 2019-02-17    NaN  ...   NaN   NaN        NaN        8.03 NaN NaN   NaN
# 2019-02-18    NaN  ...   NaN   NaN        NaN        8.02 NaN NaN   NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name        1919 유관순  4월 이야기  PMC: 더 벙커  가버나움  가위손  가장 따뜻한 색, 블루  감시자들  걸캅스  \
# date
# 2019-02-16       NaN     NaN        NaN  9.59  NaN           NaN   NaN  NaN
# 2019-02-17       NaN     NaN        NaN  9.59  NaN           NaN   NaN  NaN
# 2019-02-18       NaN     NaN        NaN  9.59  NaN           NaN   NaN  NaN
# 2019-02-19       NaN     NaN        NaN  9.59  NaN           NaN   NaN  NaN
# 2019-02-20       NaN     NaN       5.24  9.58  NaN           NaN   NaN  NaN
#
# name        공작  공포의 묘지   ...    플립  피아니스트  항거:유관순 이야기  해피 데스데이 2 유  헬보이  현기증  \
# date                     ...
# 2019-02-16 NaN     NaN   ...   NaN    NaN         NaN         8.06  NaN  NaN
# 2019-02-17 NaN     NaN   ...   NaN    NaN         NaN         8.03  NaN  NaN
# 2019-02-18 NaN     NaN   ...   NaN    NaN         NaN         8.02  NaN  NaN
# 2019-02-19 NaN     NaN   ...   NaN    NaN         NaN         7.94  NaN  NaN
# 2019-02-20 NaN     NaN   ...   NaN    NaN         NaN         7.91  NaN  NaN
#
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system()=='Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else: 
    print('Unknown system... sorry~~~')

# %%
target_col = ['PMC: 더 벙커','가버나움','해피 데스데이 2 유','혈투']
plt.figure(figsize=(12,6))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()
